# %% [markdown]
# # Plots and model selection

# %% [markdown]
# ### Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from itertools import cycle
from matplotlib import cm
from users_pass import USERPOSTGRES,PASSWORDPOSTGRES,HOST,DATABASE_NAME

# %%
# %matplotlib inline

# %% [markdown]
# ### Connect to database

# %%
user = USERPOSTGRES
password = PASSWORDPOSTGRES
host = HOST
database_name = DATABASE_NAME

db_string = f'postgresql://{user}:{password}@localhost:{host}/{database_name}'
con = create_engine(db_string)

# %%
query = '''
select * from results.metrics'''
df = pd.read_sql(query,con)
df.head(2)
# Out:
#        algorithm                    hyperparameters cohort test_fold  \
# 0  random_forest   mtry: 186 ntree: 4 nodesize: 500  small        30
# 1  random_forest  mtry: 186 ntree: 4 nodesize: 1000  small        30
#
#    threshold  sencitivity  precision        f1  auc                created_on
# 0   1.025841          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:29+00:00
# 1   1.030048          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:33+00:00

# %% [markdown]
# #### Select models run in any given date

# %%
query = f'''
select * from results.metrics where cohort = 'small'
'''
dataframe = pd.read_sql(query,con)
dataframe['learner_id'] = dataframe['algorithm']+'-'+ dataframe['hyperparameters']
dataframe.head()
# Out:
#        algorithm                    hyperparameters cohort test_fold  \
# 0  random_forest   mtry: 186 ntree: 4 nodesize: 500  small        30
# 1  random_forest  mtry: 186 ntree: 4 nodesize: 1000  small        30
# 2  random_forest  mtry: 186 ntree: 4 nodesize: 1500  small        30
# 3  random_forest   mtry: 186 ntree: 2 nodesize: 500  small        30
# 4  random_forest  mtry: 186 ntree: 2 nodesize: 1000  small        30
#
#    threshold  sencitivity  precision        f1  auc                created_on  \
# 0   1.025841          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:29+00:00
# 1   1.030048          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:33+00:00
# 2   1.028245          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:37+00:00
# 3   1.021635          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:42+00:00
# 4   1.024038          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:46+00:00
#
#                                         learner_id
# 0   random_forest-mtry: 186 ntree: 4 nodesize: 500
# 1  random_forest-mtry: 186 ntree: 4 nodesize: 1000
# 2  random_forest-mtry: 186 ntree: 4 nodesize: 1500
# 3   random_forest-mtry: 186 ntree: 2 nodesize: 500
# 4  random_forest-mtry: 186 ntree: 2 nodesize: 1000

# %% [markdown]
# ### Plots

# %%
def plot_approaches_by_fold(dataframe, metric, best_learner = ''):
    """
    Given a dataframe, metric and best_learner (optional), returns a plot.
    The plot shows the score for the metric for each learner at each fold. 
    Learners that use the same approach have the same color.
    
    Parameters
    ----------
    dataframe : dataframe
        dataframe that contains the metric,fold, algorithm and learner 
    metric: string
        metric to plot: F1,recall, etc
    best_learner: string
        learner_id selected as the best learner to be plotted in dashed line. 
    Returns
    -------
    Plot
    """
    
    data = dataframe
    approaches = data['algorithm'].unique()
    
    nrows = 1  # Number of rows
    ncols = 1 # Number of columns
    fontsize = 14 # General fontsize

    colors = cycle(['tab:blue','tab:orange','tab:green'])
    
    title = """
    Metric: {metric}"""

    # Set general setup
    fig, axis = plt.subplots(figsize = (12,6))
        
    axis.set_title(title.format(metric=metric))
    axis.set_ylabel('score')
    axis.set_ylim([0,1])
    axis.spines['top'].set_visible(False)
    axis.spines['right'].set_visible(False)
    axis.legend()

    for approach in approaches:
        c = next(colors)
        label = approach
            
        for i, learner in enumerate(data['learner_id'].unique()):                
                if learner == best_learner:
                    linestyle = 'dashed'
                    linewidth = 3
                    alpha = 0.5
                else:
                    linestyle = 'solid'
                    linewidth = 3
                    alpha = 0.5

                data_to_plot = data[(data['learner_id'] == learner) & 
                                    (data['algorithm'] == approach)]

                line = axis.plot(data_to_plot['test_fold'], data_to_plot[f'{metric}'],
                            color = c , 
                            alpha = alpha, 
                            linestyle = linestyle,
                            linewidth = linewidth,
                            label=approach if i == 0 else "")
        
                
        plt.legend(loc = 'center left', bbox_to_anchor = (1,0.5), frameon = False, title = 'metric')
    fig.tight_layout()

# %%
plot_approaches_by_fold(dataframe,'f1')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'auc')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'precision')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'sencitivity')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Select model

# %%
# Leave fold 32 out to use as independent test
dataframe_to_select = dataframe.loc[~dataframe['test_fold'].isin(['32'])]

# Rule 1: Select models with all folds AUC > 0.5
rule_1 = dataframe_to_select.loc[dataframe_to_select['auc'] < 0.5]
learners_to_drop = rule_1['learner_id'].unique()
rule_1_applied = dataframe_to_select[~dataframe_to_select.learner_id.isin(learners_to_drop)]

# Rule 2: Select models with the greatest avg auc accross all folds
dataframe_groupby_learner = rule_1_applied.groupby(['learner_id']).mean()
rule_2_applied = dataframe_groupby_learner.sort_values('auc', ascending = False).head(10)

# Rule 3: Select larger F1
rule_3_applied = rule_2_applied.sort_values('f1', ascending = False).head(1)

# %%
rule_3_applied
# Out:
#                                                threshold  sencitivity  \
# learner_id
# random_forest-mtry: 77 ntree: 6 nodesize: 500   1.043733     0.717391
#
#                                                precision        f1       auc
# learner_id
# random_forest-mtry: 77 ntree: 6 nodesize: 500   0.187062  0.212776  0.600455

# %%
rule_1_applied.shape
# Out:
# (216, 11)

# %%
plot_approaches_by_fold(rule_1_applied,'auc')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Plot ROC curve for out-of-bag test

# %%
algorithm = 'random_forest'
hyperparameters = 'mtry: 77 ntree: 6 nodesize: 500'
test_fold = '32'
cohort = 'small'

query = f'''
select * from results.predictions
where 
test_fold = '{test_fold}' 
and algorithm = '{algorithm}'
and hyperparameters = '{hyperparameters}'
and cohort = '{cohort}'
'''
df = pd.read_sql(query,con)
df['learner_id'] = df['algorithm']+'-'+ df['hyperparameters']
df.head()
# Out:
#   row.names      algorithm                  hyperparameters cohort test_fold  \
# 0     96853  random_forest  mtry: 77 ntree: 6 nodesize: 500  small        32
# 1     96858  random_forest  mtry: 77 ntree: 6 nodesize: 500  small        32
# 2     96866  random_forest  mtry: 77 ntree: 6 nodesize: 500  small        32
# 3     96868  random_forest  mtry: 77 ntree: 6 nodesize: 500  small        32
# 4     96869  random_forest  mtry: 77 ntree: 6 nodesize: 500  small        32
#
#    prediction  real                created_on  \
# 0        1.02     0 2019-09-02 20:48:57+00:00
# 1        1.02     0 2019-09-02 20:48:57+00:00
# 2        1.05     0 2019-09-02 20:48:57+00:00
# 3        1.05     0 2019-09-02 20:48:57+00:00
# 4        1.02     0 2019-09-02 20:48:57+00:00
#
#                                       learner_id
# 0  random_forest-mtry: 77 ntree: 6 nodesize: 500
# 1  random_forest-mtry: 77 ntree: 6 nodesize: 500
# 2  random_forest-mtry: 77 ntree: 6 nodesize: 500
# 3  random_forest-mtry: 77 ntree: 6 nodesize: 500
# 4  random_forest-mtry: 77 ntree: 6 nodesize: 500

# %%
from sklearn import metrics

# %%
fpr, tpr, _ = metrics.roc_curve(y_true = df['real'], y_score = df['prediction'])
auc = metrics.roc_auc_score(y_true = df['real'], y_score = df['prediction'])
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
