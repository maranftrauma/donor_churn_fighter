# %% [markdown]
# # Plots and model selection

# %% [markdown]
# ### Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from itertools import cycle
from matplotlib import cm
from sklearn import metrics
import pathlib

# %%
# %matplotlib inline

# %% [markdown]
# ### Connect to database

# %%
db_string = 'postgresql://postgres:123456@localhost:5432/donaronline_boosted'
con = create_engine(db_string)

# %%
query = '''
select * from results.metrics'''
df = pd.read_sql(query,con)
df.head(2)
# Out:
#        algorithm                    hyperparameters cohort test_fold  \
# 0  random_forest   mtry: 186 ntree: 4 nodesize: 500  small        30
# 1  random_forest  mtry: 186 ntree: 4 nodesize: 1000  small        30
#
#    threshold  sencitivity  precision        f1  auc                created_on
# 0   1.025841          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:29+00:00
# 1   1.030048          1.0   0.016981  0.033395  0.5 2019-09-02 20:43:33+00:00

# %% [markdown]
# #### Select models run in any given date

# %%
query = f'''
select * from results.metrics where cohort = 'large'
'''
dataframe = pd.read_sql(query,con)
dataframe['learner_id'] = dataframe['algorithm']+'-'+ dataframe['hyperparameters']

# Leave fold 32 out to use as independent test
dataframe = dataframe.loc[~dataframe['test_fold'].isin(['32'])]
dataframe.head()
# Out:
#        algorithm                    hyperparameters cohort test_fold  \
# 0  random_forest   mtry: 186 ntree: 500 nodesize: 4  large         2
# 1  random_forest   mtry: 186 ntree: 500 nodesize: 2  large         2
# 2  random_forest   mtry: 186 ntree: 500 nodesize: 6  large         2
# 3  random_forest  mtry: 186 ntree: 1000 nodesize: 4  large         2
# 4  random_forest  mtry: 186 ntree: 1000 nodesize: 2  large         2
#
#    threshold  sencitivity  precision        f1       auc  \
# 0   1.003167       0.9375   0.038462  0.073892  0.817717
# 1   1.009000       0.9375   0.039267  0.075377  0.791902
# 2   1.005900       0.9375   0.038363  0.073710  0.817880
# 3   1.008250       0.9375   0.039062  0.075000  0.797772
# 4   1.008000       0.9375   0.039267  0.075377  0.789946
#
#                  created_on                                       learner_id
# 0 2019-09-03 13:21:22+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 4
# 1 2019-09-03 13:21:28+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 2
# 2 2019-09-03 13:21:35+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 6
# 3 2019-09-03 13:21:44+00:00  random_forest-mtry: 186 ntree: 1000 nodesize: 4
# 4 2019-09-03 13:21:53+00:00  random_forest-mtry: 186 ntree: 1000 nodesize: 2

# %% [markdown]
# ### Plots

# %%
def plot_approaches_by_fold(dataframe, metric, best_learner = ''):
    """
    Given a dataframe, metric and best_learner (optional), returns a plot.
    The plot shows the score for the metric for each learner at each fold. 
    Learners that use the same approach have the same color.
    
    Parameters
    ----------
    dataframe : dataframe
        dataframe that contains the metric,fold, algorithm and learner 
    metric: string
        metric to plot: F1,recall, etc
    best_learner: string
        learner_id selected as the best learner to be plotted in dashed line. 
    Returns
    -------
    Plot
    """
    
    data = dataframe
    approaches = data['algorithm'].unique()
    
    nrows = 1  # Number of rows
    ncols = 1 # Number of columns
    fontsize = 14 # General fontsize
    
    # Blindcolor friendly colours
    colors = cycle(['#377eb8', '#ff7f00', '#4daf4a'])
    
    title = """
    Metric: {metric}"""

    # Set general setup
    fig, axis = plt.subplots(figsize = (12,6))
        
    axis.set_title(title.format(metric=metric))
    axis.set_ylabel('score')
    axis.set_ylim([0,1])
    axis.spines['top'].set_visible(False)
    axis.spines['right'].set_visible(False)
    axis.legend()

    for approach in approaches:
        approach_color = next(colors)
        label = approach
            
        for i, learner in enumerate(data['learner_id'].unique()):                
                if learner == best_learner:
                    linestyle = 'dashed'
                    linewidth = 7
                    alpha = 1
                    c = '#e41a1c'
                    #label = 'best_model'
                             
                else:
                    linestyle = 'solid'
                    linewidth = 2
                    alpha = 0.3
                    c = approach_color
                    label=approach if i == 0 else ""
                    
                data_to_plot = data[(data['learner_id'] == learner) & 
                                    (data['algorithm'] == approach)]

                line = axis.plot(data_to_plot['test_fold'], data_to_plot[f'{metric}'],
                            color = c , 
                            alpha = alpha, 
                            linestyle = linestyle,
                            linewidth = linewidth,
                            label=label)
                c = approach_color
                
        plt.legend(loc = 'center left', bbox_to_anchor = (1,0.5), frameon = False, title = 'metric')
    fig.tight_layout()
    
    # Save to disc
    name_file = lambda best_learner: 'plot_approaches_by_fold_' + f'{metric}' + '.png' if best_learner == '' else 'best_model_' + 'plot_approaches_by_fold_' + f'{metric}' + '.png'
    file_to_save = pathlib.Path.cwd().joinpath('images',f'{name_file(best_learner)}')
    plt.savefig(file_to_save)

# %%
plot_approaches_by_fold(dataframe,'f1')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'auc')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'precision')
# Out:
# No handles with labels found to put in legend.

# %%
plot_approaches_by_fold(dataframe,'sencitivity')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Select model

# %%
# Rule 1: Select models with all folds AUC > 0.5
rule_1 = dataframe.loc[dataframe['auc'] < 0.5]
learners_to_drop = rule_1['learner_id'].unique()
rule_1_applied = dataframe[~dataframe.learner_id.isin(learners_to_drop)]

# Rule 2: Select models with the greatest avg auc accross all folds
dataframe_groupby_learner = rule_1_applied.groupby(['learner_id']).mean()
rule_2_applied = dataframe_groupby_learner.sort_values('auc', ascending = False).head(10)

# Rule 3: Select larger F1
rule_3_applied = rule_2_applied.sort_values('f1', ascending = False).head(1)

# %%
rule_2_applied
# Out:
#                                                     threshold  sencitivity  \
# learner_id
# random_forest-mtry: 15 ntree: 1500 nodesize: 4       1.023490     0.975129
# random_forest-mtry: 15 ntree: 500 nodesize: 6        1.024875     0.971479
# random_forest-mtry: 15 ntree: 1000 nodesize: 4       1.022841     0.985241
# random_forest-mtry: 15 ntree: 1500 nodesize: 6       1.022765     0.981380
# random_forest-mtry: 15 ntree: 1000 nodesize: 2       1.024243     0.970279
# extra_trees-mtry: 186 ntree: 1500 nodesize: 2 n...   1.000000     0.057207
# extra_trees-mtry: 15 ntree: 500 nodesize: 2 num...   1.000000     0.057207
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...   1.000000     0.057279
# extra_trees-mtry: 186 ntree: 500 nodesize: 2 nu...   1.000000     0.057279
# extra_trees-mtry: 77 ntree: 500 nodesize: 2 num...   1.000000     0.057279
#
#                                                     precision        f1  \
# learner_id
# random_forest-mtry: 15 ntree: 1500 nodesize: 4       0.047968  0.084738
# random_forest-mtry: 15 ntree: 500 nodesize: 6        0.049864  0.087595
# random_forest-mtry: 15 ntree: 1000 nodesize: 4       0.048444  0.085210
# random_forest-mtry: 15 ntree: 1500 nodesize: 6       0.047351  0.083591
# random_forest-mtry: 15 ntree: 1000 nodesize: 2       0.047703  0.084190
# extra_trees-mtry: 186 ntree: 1500 nodesize: 2 n...   0.928571  0.348529
# extra_trees-mtry: 15 ntree: 500 nodesize: 2 num...   0.928571  0.348529
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...   0.928571  0.349077
# extra_trees-mtry: 186 ntree: 500 nodesize: 2 nu...   0.928571  0.349077
# extra_trees-mtry: 77 ntree: 500 nodesize: 2 num...   0.928571  0.349077
#
#                                                          auc
# learner_id
# random_forest-mtry: 15 ntree: 1500 nodesize: 4      0.715162
# random_forest-mtry: 15 ntree: 500 nodesize: 6       0.710195
# random_forest-mtry: 15 ntree: 1000 nodesize: 4      0.710137
# random_forest-mtry: 15 ntree: 1500 nodesize: 6      0.709726
# random_forest-mtry: 15 ntree: 1000 nodesize: 2      0.709530
# extra_trees-mtry: 186 ntree: 1500 nodesize: 2 n...  0.702191
# extra_trees-mtry: 15 ntree: 500 nodesize: 2 num...  0.700948
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...  0.698895
# extra_trees-mtry: 186 ntree: 500 nodesize: 2 nu...  0.696536
# extra_trees-mtry: 77 ntree: 500 nodesize: 2 num...  0.696050

# %% [markdown]
# ##### Selected model

# %%
best_model = rule_3_applied
best_model
# Out:
#                                                     threshold  sencitivity  \
# learner_id
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...        1.0     0.057279
#
#                                                     precision        f1  \
# learner_id
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...   0.928571  0.349077
#
#                                                          auc
# learner_id
# extra_trees-mtry: 15 ntree: 1500 nodesize: 2 nu...  0.698895

# %%
list(best_model.index)
# Out:
# ['extra_trees-mtry: 15 ntree: 1500 nodesize: 2 numRandomCuts: 1']

# %% [markdown]
# #### Plot ROC curve for out-of-bag test

# %%
# Best model
algorithm = 'extra_trees'
hyperparameters = 'mtry: 15 ntree: 1500 nodesize: 2 numRandomCuts: 1'
test_fold = '32'
cohort = 'large'

# Retrieve prediction data of the best model
query = f'''
select * from results.predictions
where 
test_fold = '{test_fold}' 
and algorithm = '{algorithm}'
and hyperparameters = '{hyperparameters}'
and cohort = '{cohort}'
'''
df = pd.read_sql(query,con)

# Create a column to identify learner: Algorithm name - hyperparameters
df['learner_id'] = df['algorithm']+'-'+ df['hyperparameters']

# %%
# Calculate metrics
fpr, tpr, _ = metrics.roc_curve(y_true = df['real'], y_score = df['prediction'])
auc = metrics.roc_auc_score(y_true = df['real'], y_score = df['prediction'])

# Plot
## Set up
fig, axis = plt.subplots(figsize = (12,6))

# Plotting
plt.plot(fpr,tpr,
         label="Best model AUC="+str(round(auc,3)), 
         c = '#4daf4a' ,
         linestyle = 'solid',
         linewidth = 2)
plt.plot([0,1],[0,1], 
         c = 'black',
         label = 'Random classifier')
plt.legend(loc=4)
fig.tight_layout()
fig.show()

# Save to disc
name_file = 'ROC_Best_model' + '.png'
file_to_save = pathlib.Path.cwd().joinpath('images',f'{name_file}')
plt.savefig(file_to_save)
# Out:
# /Users/mac/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
ploty = plot_approaches_by_fold(dataframe,
                                'auc', 
                                best_learner = 'extra_trees-mtry: 15 ntree: 1500 nodesize: 2 numRandomCuts: 1')
# Out:
# No handles with labels found to put in legend.

# %%
dataframe.head()
# Out:
#        algorithm                    hyperparameters cohort test_fold  \
# 0  random_forest   mtry: 186 ntree: 500 nodesize: 4  large         2
# 1  random_forest   mtry: 186 ntree: 500 nodesize: 2  large         2
# 2  random_forest   mtry: 186 ntree: 500 nodesize: 6  large         2
# 3  random_forest  mtry: 186 ntree: 1000 nodesize: 4  large         2
# 4  random_forest  mtry: 186 ntree: 1000 nodesize: 2  large         2
#
#    threshold  sencitivity  precision        f1       auc  \
# 0   1.003167       0.9375   0.038462  0.073892  0.817717
# 1   1.009000       0.9375   0.039267  0.075377  0.791902
# 2   1.005900       0.9375   0.038363  0.073710  0.817880
# 3   1.008250       0.9375   0.039062  0.075000  0.797772
# 4   1.008000       0.9375   0.039267  0.075377  0.789946
#
#                  created_on                                       learner_id
# 0 2019-09-03 13:21:22+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 4
# 1 2019-09-03 13:21:28+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 2
# 2 2019-09-03 13:21:35+00:00   random_forest-mtry: 186 ntree: 500 nodesize: 6
# 3 2019-09-03 13:21:44+00:00  random_forest-mtry: 186 ntree: 1000 nodesize: 4
# 4 2019-09-03 13:21:53+00:00  random_forest-mtry: 186 ntree: 1000 nodesize: 2

# %%
nrows = 1  # Number of rows
ncols = 1 # Number of columns
fontsize = 14 # General fontsize
     
title = """
Metric: {metric}"""

# Set general setup
fig, axis = plt.subplots(figsize = (12,6))
        
#axis.set_title(title.format('metric'))
axis.set_ylabel('score')
axis.set_ylim([0,1])
axis.spines['top'].set_visible(False)
axis.spines['right'].set_visible(False)
axis.legend()

# Line setup
linestyle = 'dashed'
linewidth = 2
alpha = 1
c = '#4daf4a'

learner = str(list(best_model.index)).strip("['']")

# Select data on best model
data_to_plot = dataframe[(dataframe['learner_id'] == learner)] 

# Plot using the selected data
line = axis.plot(data_to_plot['test_fold'], data_to_plot['auc'],
                    color = c , 
                    alpha = alpha, 
                    linestyle = linestyle,
                    linewidth = linewidth,
                    label='best model')

plt.legend(loc = 'center left', bbox_to_anchor = (1,0.5), frameon = False, title = 'metric')
fig.tight_layout()

# Save to disc
name_file = 'Best_Model_AUC_by_Fold' + '.png'
file_to_save = pathlib.Path.cwd().joinpath('images',f'{name_file}')
plt.savefig(file_to_save)
# Out:
# No handles with labels found to put in legend.
